# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
train_df = pd.read_csv("task2/data/train.csv")

test_df = pd.read_csv("task2/data/test.csv")

# %%
test_df.isnull().sum()
# Out:
# season        0
# price_AUS    33
# price_CZE    25
# price_GER    31
# price_ESP    39
# price_FRA    25
# price_UK     24
# price_ITA    30
# price_POL    35
# price_SVK    34
# dtype: int64

# %%
train_df.isnull().sum()
# Out:
# season         0
# price_AUS    262
# price_CHF    269
# price_CZE    268
# price_GER    269
# price_ESP    269
# price_FRA    264
# price_UK     287
# price_ITA    266
# price_POL    265
# price_SVK    281
# dtype: int64

# %%
test_df
# Out:
#     season  price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  \
# 0   spring        NaN   0.472985   0.707957        NaN  -1.136441 -0.596703
# 1   summer  -1.184837   0.358019        NaN  -3.199028  -1.069695       NaN
# 2   autumn  -1.116459        NaN   0.780460  -3.338948  -1.053149 -0.586339
# 3   winter        NaN   0.353066   0.833429        NaN  -1.322626 -0.628873
# 4   spring        NaN   0.269644        NaN  -3.245495  -1.362051 -0.717914
# ..     ...        ...        ...        ...        ...        ...       ...
# 95  winter  -2.030894        NaN  -1.332104  -3.838154        NaN -2.319565
# 96  spring  -1.817763        NaN        NaN  -3.995247  -3.760752       NaN
# 97  summer        NaN        NaN  -1.140538  -4.084448  -3.968988 -2.555133
# 98  autumn        NaN  -1.029762        NaN  -4.216490  -3.705548 -2.487751
# 99  winter  -1.472852  -0.935032        NaN  -4.463277  -3.488559       NaN
#
#     price_ITA  price_POL  price_SVK
# ...

# %%
train_df
# Out:
#      season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0    spring        NaN   9.644028  -1.686248  -1.748076  -3.666005        NaN
# 1    summer        NaN   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
# 2    autumn  -2.101937   7.620085  -1.910282        NaN  -3.388777        NaN
# 3    winter  -2.098475   8.411894  -1.903834        NaN  -3.588235        NaN
# 4    spring  -1.969687   8.926884  -1.697257  -1.331049        NaN  -3.911096
# ..      ...        ...        ...        ...        ...        ...        ...
# 895  winter  -1.044730        NaN   0.190134   0.253153  -3.443941  -1.967611
# 896  spring  -1.061639  -1.734754   0.281646        NaN  -3.466753  -1.929701
# 897  summer  -0.971157        NaN   0.245279   0.558474        NaN        NaN
# 898  autumn        NaN        NaN   0.299911   0.788152  -3.339650        NaN
# 899  winter  -1.058343        NaN   0.231835   0.800460  -3.377680  -1.200493
#
# ...

# %%
train_df_new = train_df.dropna(subset='price_CHF')
train_df_new
# Out:
#      season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0    spring        NaN   9.644028  -1.686248  -1.748076  -3.666005        NaN
# 1    summer        NaN   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
# 2    autumn  -2.101937   7.620085  -1.910282        NaN  -3.388777        NaN
# 3    winter  -2.098475   8.411894  -1.903834        NaN  -3.588235        NaN
# 4    spring  -1.969687   8.926884  -1.697257  -1.331049        NaN  -3.911096
# ..      ...        ...        ...        ...        ...        ...        ...
# 889  summer        NaN   3.237347   0.235917  -0.306331        NaN  -2.735177
# 890  autumn  -1.079859   2.679221        NaN  -0.226806        NaN        NaN
# 891  winter  -0.961371   3.633928   0.352449        NaN  -3.488688        NaN
# 894  autumn  -1.186919  -0.303802        NaN   0.236214  -3.333672  -2.262145
# 896  spring  -1.061639  -1.734754   0.281646        NaN  -3.466753  -1.929701
#
# ...

# %%
test_df_new = test_df

# %%
le = LabelEncoder()
label = le.fit_transform(train_df_new['season'])
label_test = le.fit_transform(test_df_new['season'])

train_df_new['season'] = label
test_df_new['season'] = label_test
# Out:
# C:\Users\timfl\AppData\Local\Temp\ipykernel_9696\2216429546.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_new['season'] = label

# %%
train_df_new
# Out:
#      season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0         1        NaN   9.644028  -1.686248  -1.748076  -3.666005        NaN
# 1         2        NaN   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
# 2         0  -2.101937   7.620085  -1.910282        NaN  -3.388777        NaN
# 3         3  -2.098475   8.411894  -1.903834        NaN  -3.588235        NaN
# 4         1  -1.969687   8.926884  -1.697257  -1.331049        NaN  -3.911096
# ..      ...        ...        ...        ...        ...        ...        ...
# 889       2        NaN   3.237347   0.235917  -0.306331        NaN  -2.735177
# 890       0  -1.079859   2.679221        NaN  -0.226806        NaN        NaN
# 891       3  -0.961371   3.633928   0.352449        NaN  -3.488688        NaN
# 894       0  -1.186919  -0.303802        NaN   0.236214  -3.333672  -2.262145
# 896       1  -1.061639  -1.734754   0.281646        NaN  -3.466753  -1.929701
#
# ...

# %%
test_df_new
# Out:
#     season  price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  \
# 0        1        NaN   0.472985   0.707957        NaN  -1.136441 -0.596703
# 1        2  -1.184837   0.358019        NaN  -3.199028  -1.069695       NaN
# 2        0  -1.116459        NaN   0.780460  -3.338948  -1.053149 -0.586339
# 3        3        NaN   0.353066   0.833429        NaN  -1.322626 -0.628873
# 4        1        NaN   0.269644        NaN  -3.245495  -1.362051 -0.717914
# ..     ...        ...        ...        ...        ...        ...       ...
# 95       3  -2.030894        NaN  -1.332104  -3.838154        NaN -2.319565
# 96       1  -1.817763        NaN        NaN  -3.995247  -3.760752       NaN
# 97       2        NaN        NaN  -1.140538  -4.084448  -3.968988 -2.555133
# 98       0        NaN  -1.029762        NaN  -4.216490  -3.705548 -2.487751
# 99       3  -1.472852  -0.935032        NaN  -4.463277  -3.488559       NaN
#
#     price_ITA  price_POL  price_SVK
# ...

# %%
train_df
# Out:
#      season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0    spring        NaN   9.644028  -1.686248  -1.748076  -3.666005        NaN
# 1    summer        NaN   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
# 2    autumn  -2.101937   7.620085  -1.910282        NaN  -3.388777        NaN
# 3    winter  -2.098475   8.411894  -1.903834        NaN  -3.588235        NaN
# 4    spring  -1.969687   8.926884  -1.697257  -1.331049        NaN  -3.911096
# ..      ...        ...        ...        ...        ...        ...        ...
# 895  winter  -1.044730        NaN   0.190134   0.253153  -3.443941  -1.967611
# 896  spring  -1.061639  -1.734754   0.281646        NaN  -3.466753  -1.929701
# 897  summer  -0.971157        NaN   0.245279   0.558474        NaN        NaN
# 898  autumn        NaN        NaN   0.299911   0.788152  -3.339650        NaN
# 899  winter  -1.058343        NaN   0.231835   0.800460  -3.377680  -1.200493
#
# ...

# %%
train_df_new.groupby(['season'])['price_AUS'].median().round(2)
# Out:
# season
# 0   -0.78
# 1   -0.52
# 2   -0.69
# 3   -0.48
# Name: price_AUS, dtype: float64

# %%
train_df_new.columns[1]
# Out:
# 'price_AUS'

# %%
for item in train_df_new.columns:
    train_df_new[item] = train_df_new.groupby('season')[item].transform(lambda x: x.fillna(x.median()))
for item in test_df_new.columns:
    test_df_new[item] = test_df_new.groupby('season')[item].transform(lambda x: x.fillna(x.median()))
# Out:
# C:\Users\timfl\AppData\Local\Temp\ipykernel_9696\1614013212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_new[item] = train_df_new.groupby('season')[item].transform(lambda x: x.fillna(x.median()))
# C:\Users\timfl\AppData\Local\Temp\ipykernel_9696\1614013212.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df_new[item] = train_df_new.groupby('season')[item].transform(lambda x: x.fillna(x.median()))
# ...

# %%
train_df
# Out:
#      season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0    spring        NaN   9.644028  -1.686248  -1.748076  -3.666005        NaN
# 1    summer        NaN   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
# 2    autumn  -2.101937   7.620085  -1.910282        NaN  -3.388777        NaN
# 3    winter  -2.098475   8.411894  -1.903834        NaN  -3.588235        NaN
# 4    spring  -1.969687   8.926884  -1.697257  -1.331049        NaN  -3.911096
# ..      ...        ...        ...        ...        ...        ...        ...
# 895  winter  -1.044730        NaN   0.190134   0.253153  -3.443941  -1.967611
# 896  spring  -1.061639  -1.734754   0.281646        NaN  -3.466753  -1.929701
# 897  summer  -0.971157        NaN   0.245279   0.558474        NaN        NaN
# 898  autumn        NaN        NaN   0.299911   0.788152  -3.339650        NaN
# 899  winter  -1.058343        NaN   0.231835   0.800460  -3.377680  -1.200493
#
# ...

# %%
train_df_new
# Out:
#      season  price_AUS  price_CHF  price_CZE  price_GER  price_ESP  price_FRA  \
# 0         1  -0.519757   9.644028  -1.686248  -1.748076  -3.666005  -3.176436
# 1         2  -0.689416   7.246061  -2.132377  -2.054363  -3.295697  -4.104759
# 2         0  -2.101937   7.620085  -1.910282  -0.379059  -3.388777  -3.396470
# 3         3  -2.098475   8.411894  -1.903834  -0.146333  -3.588235  -3.286866
# 4         1  -1.969687   8.926884  -1.697257  -1.331049  -4.393997  -3.911096
# ..      ...        ...        ...        ...        ...        ...        ...
# 889       2  -0.689416   3.237347   0.235917  -0.306331  -4.237861  -2.735177
# 890       0  -1.079859   2.679221  -0.113687  -0.226806  -4.425276  -3.396470
# 891       3  -0.961371   3.633928   0.352449  -0.146333  -3.488688  -3.286866
# 894       0  -1.186919  -0.303802  -0.113687   0.236214  -3.333672  -2.262145
# 896       1  -1.061639  -1.734754   0.281646  -0.230815  -3.466753  -1.929701
#
# ...

# %%
test_df_new
# Out:
#     season  price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  \
# 0        1  -1.428443   0.472985   0.707957  -3.609895  -1.136441 -0.596703
# 1        2  -1.184837   0.358019  -1.344293  -3.199028  -1.069695 -2.103320
# 2        0  -1.116459  -1.418303   0.780460  -3.338948  -1.053149 -0.586339
# 3        3  -1.394824   0.353066   0.833429  -3.931837  -1.322626 -0.628873
# 4        1  -1.428443   0.269644  -1.032372  -3.245495  -1.362051 -0.717914
# ..     ...        ...        ...        ...        ...        ...       ...
# 95       3  -2.030894  -1.217764  -1.332104  -3.838154  -3.777239 -2.319565
# 96       1  -1.817763  -1.047298  -1.032372  -3.995247  -3.760752 -2.137154
# 97       2  -1.449465  -1.493495  -1.140538  -4.084448  -3.968988 -2.555133
# 98       0  -1.430368  -1.029762  -0.854572  -4.216490  -3.705548 -2.487751
# 99       3  -1.472852  -0.935032  -1.167556  -4.463277  -3.488559 -2.159804
#
#     price_ITA  price_POL  price_SVK
# ...

# %%
test_df
# Out:
#     season  price_AUS  price_CZE  price_GER  price_ESP  price_FRA  price_UK  \
# 0   spring        NaN   0.472985   0.707957        NaN  -1.136441 -0.596703
# 1   summer  -1.184837   0.358019        NaN  -3.199028  -1.069695       NaN
# 2   autumn  -1.116459        NaN   0.780460  -3.338948  -1.053149 -0.586339
# 3   winter        NaN   0.353066   0.833429        NaN  -1.322626 -0.628873
# 4   spring        NaN   0.269644        NaN  -3.245495  -1.362051 -0.717914
# ..     ...        ...        ...        ...        ...        ...       ...
# 95  winter  -2.030894        NaN  -1.332104  -3.838154        NaN -2.319565
# 96  spring  -1.817763        NaN        NaN  -3.995247  -3.760752       NaN
# 97  summer        NaN        NaN  -1.140538  -4.084448  -3.968988 -2.555133
# 98  autumn        NaN  -1.029762        NaN  -4.216490  -3.705548 -2.487751
# 99  winter  -1.472852  -0.935032        NaN  -4.463277  -3.488559       NaN
#
#     price_ITA  price_POL  price_SVK
# ...

# %%
X_train = train_df_new.drop(['price_CHF'], axis = 1)
y_train = train_df_new['price_CHF']
X_test = test_df_new

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic, ExpSineSquared, DotProduct, ConstantKernel)
gpr = GaussianProcessRegressor(kernel=DotProduct())
gpr.fit(X_train, y_train)
# Out:
# GaussianProcessRegressor(kernel=DotProduct(sigma_0=1))

# %%
pred = gpr.predict(X_test)

# %%
kernel = gpr.kernel_

# %%
kernel
# Out:
# DotProduct(sigma_0=0.0155)

# %%
from sklearn.model_selection import GridSearchCV

models = GaussianProcessRegressor()
                
param_grid = [{
    "alpha":  [1e-2, 1e-3],
    "kernel": [RBF(l) for l in np.logspace(-1, 1, 2)]
}, {
    "alpha":  [1e-2, 1e-3],
    "kernel": [DotProduct(sigma_0) for sigma_0 in np.logspace(-1, 1, 2)]
}, {
    "alpha":  [1e-2, 1e-3],
    "kernel": [Matern(length_scale=1.0, nu=1.5)]
    
}]

# %%
clf = GridSearchCV(models, param_grid)
clf.fit(X_train, y_train)
# Out:
# C:\Users\timfl\anaconda3\envs\IML\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\timfl\anaconda3\envs\IML\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\timfl\anaconda3\envs\IML\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
print(clf.best_params_)
# Out:
# {'alpha': 0.01, 'kernel': Matern(length_scale=1, nu=1.5)}
